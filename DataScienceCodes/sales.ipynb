# %%
import pandas as pd

df = pd.read_csv('sales.csv')

# %%
df.head(10)
# Out:
#    Order ID  Customer Name   Order Date   Product  Quantity  Unit Price  \
# 0      1001       John Doe   01/01/2024  Widget A      10.0        25.0
# 1      1002     Jane Smith   01/02/2024  Widget B       5.0        40.0
# 2      1003            NaN  2024/01/03'  Widget A       NaN        25.0
# 3      1004  Alice Johnson   04/01/2024  Widget C       3.0         NaN
# 4      1005      Bob Brown  2024/01/05'  Widget B      10.0        40.0
# 5      1006       John Doe   06/01/2024  Widget A       4.0        25.0
# 6      1001       John Doe   01/01/2024  Widget A      10.0        25.0
# 7      1007     Jane Smith   07/01/2024  Widget C      -6.0        70.0
#
#    Total Revenue
# 0          250.0
# 1          200.0
# 2            NaN
# 3          210.0
# 4          400.0
# 5          100.0
# 6          250.0
# 7         -420.0

# %%
df.loc[7, 'Quantity'] = 6
df.loc[7, 'Total Revenue'] = 420
df
# Out:
#    Order ID  Customer Name   Order Date   Product  Quantity  Unit Price  \
# 0      1001       John Doe   01/01/2024  Widget A      10.0        25.0
# 1      1002     Jane Smith   01/02/2024  Widget B       5.0        40.0
# 2      1003            NaN  2024/01/03'  Widget A       NaN        25.0
# 3      1004  Alice Johnson   04/01/2024  Widget C       3.0         NaN
# 4      1005      Bob Brown  2024/01/05'  Widget B      10.0        40.0
# 5      1006       John Doe   06/01/2024  Widget A       4.0        25.0
# 6      1001       John Doe   01/01/2024  Widget A      10.0        25.0
# 7      1007     Jane Smith   07/01/2024  Widget C       6.0        70.0
#
#    Total Revenue
# 0          250.0
# 1          200.0
# 2            NaN
# 3          210.0
# 4          400.0
# 5          100.0
# 6          250.0
# 7          420.0

# %%
x = df[['Quantity', 'Unit Price', 'Total Revenue']].median()
df.fillna(value = x, inplace = True)
df
# Out:
#    Order ID  Customer Name   Order Date   Product  Quantity  Unit Price  \
# 0      1001       John Doe   01/01/2024  Widget A      10.0        25.0
# 1      1002     Jane Smith   01/02/2024  Widget B       5.0        40.0
# 2      1003            NaN  2024/01/03'  Widget A       6.0        25.0
# 3      1004  Alice Johnson   04/01/2024  Widget C       3.0        25.0
# 4      1005      Bob Brown  2024/01/05'  Widget B      10.0        40.0
# 5      1006       John Doe   06/01/2024  Widget A       4.0        25.0
# 6      1001       John Doe   01/01/2024  Widget A      10.0        25.0
# 7      1007     Jane Smith   07/01/2024  Widget C       6.0        70.0
#
#    Total Revenue
# 0          250.0
# 1          200.0
# 2          250.0
# 3          210.0
# 4          400.0
# 5          100.0
# 6          250.0
# 7          420.0

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format = 'mixed')
df
# Out:
#    Order ID  Customer Name Order Date   Product  Quantity  Unit Price  \
# 0      1001       John Doe 2024-01-01  Widget A      10.0        25.0
# 1      1002     Jane Smith 2024-01-02  Widget B       5.0        40.0
# 2      1003            NaN 2024-01-03  Widget A       6.0        25.0
# 3      1004  Alice Johnson 2024-04-01  Widget C       3.0        25.0
# 4      1005      Bob Brown 2024-01-05  Widget B      10.0        40.0
# 5      1006       John Doe 2024-06-01  Widget A       4.0        25.0
# 6      1001       John Doe 2024-01-01  Widget A      10.0        25.0
# 7      1007     Jane Smith 2024-07-01  Widget C       6.0        70.0
#
#    Total Revenue
# 0          250.0
# 1          200.0
# 2          250.0
# 3          210.0
# 4          400.0
# 5          100.0
# 6          250.0
# 7          420.0

# %%
print("Number of duplicates: ", df.duplicated().sum())
# Out:
# Number of duplicates:  1

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#    Order ID  Customer Name Order Date   Product  Quantity  Unit Price  \
# 0      1001       John Doe 2024-01-01  Widget A      10.0        25.0
# 1      1002     Jane Smith 2024-01-02  Widget B       5.0        40.0
# 2      1003            NaN 2024-01-03  Widget A       6.0        25.0
# 3      1004  Alice Johnson 2024-04-01  Widget C       3.0        25.0
# 4      1005      Bob Brown 2024-01-05  Widget B      10.0        40.0
# 5      1006       John Doe 2024-06-01  Widget A       4.0        25.0
# 7      1007     Jane Smith 2024-07-01  Widget C       6.0        70.0
#
#    Total Revenue
# 0          250.0
# 1          200.0
# 2          250.0
# 3          210.0
# 4          400.0
# 5          100.0
# 7          420.0

# %%
df.dropna(inplace = True)
df
# Out:
#    Order ID  Customer Name Order Date   Product  Quantity  Unit Price  \
# 0      1001       John Doe 2024-01-01  Widget A      10.0        25.0
# 1      1002     Jane Smith 2024-01-02  Widget B       5.0        40.0
# 3      1004  Alice Johnson 2024-04-01  Widget C       3.0        25.0
# 4      1005      Bob Brown 2024-01-05  Widget B      10.0        40.0
# 5      1006       John Doe 2024-06-01  Widget A       4.0        25.0
# 7      1007     Jane Smith 2024-07-01  Widget C       6.0        70.0
#
#    Total Revenue
# 0          250.0
# 1          200.0
# 3          210.0
# 4          400.0
# 5          100.0
# 7          420.0

# %%
df.loc[3, 'Total Revenue'] = 75
df
# Out:
#    Order ID  Customer Name Order Date   Product  Quantity  Unit Price  \
# 0      1001       John Doe 2024-01-01  Widget A      10.0        25.0
# 1      1002     Jane Smith 2024-01-02  Widget B       5.0        40.0
# 3      1004  Alice Johnson 2024-04-01  Widget C       3.0        25.0
# 4      1005      Bob Brown 2024-01-05  Widget B      10.0        40.0
# 5      1006       John Doe 2024-06-01  Widget A       4.0        25.0
# 7      1007     Jane Smith 2024-07-01  Widget C       6.0        70.0
#
#    Total Revenue
# 0          250.0
# 1          200.0
# 3           75.0
# 4          400.0
# 5          100.0
# 7          420.0
